# %%
import requests 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import pandas as pd

# 동적 웹페이지 불러오기
driver = webdriver.Chrome()
driver.get('https://movie.daum.net/moviedb/grade?movieId=111292')
time.sleep(3)


# 맨 마지막 페이지까지 더보기 클릭
for k in range(99999):
    try:
        driver.find_element(By.XPATH, '//*[@id="alex-area"]/div/div/div/div[3]/div[1]/button').click() 
        time.sleep(1)
    except Exception as ex:
        
        break;

html = driver.page_source
soup = BeautifulSoup(html, "lxml")        

# 빈 리스트 생성
rating_list = [] 
review_list = []

# 리뷰내용과 점수 크롤링
box_list= soup.select('.cmt_info')
for box in box_list:
    try :
        review= box.select_one('p.desc_txt').text
    except :
        review= "no review"
    rating= box.select_one('.ratings').text
    
    review_list.append(review)
    rating_list.append(rating)

# 데이터프레임생성
info = {"rating" : rating_list , "review" : review_list}   

parasite = pd.DataFrame(info)

# %%
parasite
# Out:
#      rating                                             review
# 0        10  현재는시골에서  열댓마리 강아지와 살고있다. 서울서는  지하에 내리 살았어서 그 냄...
# 1         9  유럽 친구가 내 의견 궁금하다고 꼭 봐 보래서 구입해서 봐 봤는데\n송강호가 이선균...
# 2        10            기분이 나빠진다.\n김선균에게 이입하고 싶지만 송강호인 현실이 슬프다.
# 3        10  시대의 명작. 평점이 낮은 이유는 저급한 댓글알바들과 봉준호를 싫어하는 ♪♬들이 여...
# 4        10                                 몇번이나 다시봐도 진짜 명작입니다
# ...     ...                                                ...
# 8655      1  평점이 좋은 이유를 모르겠네요. ㅎ\n영화보는 눈이 아둔해서 그런가\n무슨 메시지를...
# 8656      1                         이런게 영화면 성냥팔이 소녀의 재림은 신화다 ㅋ
# 8657      2  별점 1점도 아깝다\n어떤 사람이 이 영화를 봤는데 처음에는 재미 있었지만 나중에는...
# 8658     10                              좌파폭도고발영화.전라도까는 내용이었어.
# 8659      1  너무\n없이사는 사람들 비하 아닌가?\n넷플서 드디어 봤는데\n진짜 불쾌하네\n봉감...
#
# [8660 rows x 2 columns]
